# %%
# !pip install ultralytics
from ultralytics import YOLO
import torch

import matplotlib.pyplot as plt
from PIL import Image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 695.2/695.2 kB 3.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/YOLOv8 Training Results-20240109T003921Z-001.zip', 'r')
zip_ref.extractall('/content/YOLOv8_training_results/')
zip_ref.close()

# %% [markdown]
# ## Go through all Metrics

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/F1_curve.png'))
plt.axis('off')
# Out:
# (-0.5, 2249.5, 1499.5, -0.5)

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/PR_curve.png'))
plt.axis('off')
# Out:
# (-0.5, 2249.5, 1499.5, -0.5)

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/P_curve.png'))
plt.axis('off')
# Out:
# (-0.5, 2249.5, 1499.5, -0.5)

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/R_curve.png'))
plt.axis('off')
# Out:
# (-0.5, 2249.5, 1499.5, -0.5)

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/labels.jpg'))
plt.axis('off')
# Out:
# (-0.5, 1599.5, 1599.5, -0.5)

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/results.png'))
plt.axis('off')
# Out:
# (-0.5, 2399.5, 1199.5, -0.5)

# %% [markdown]
# Training Batches

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/train_batch0.jpg'))
plt.axis('off')
# Out:
# (-0.5, 1919.5, 1919.5, -0.5)

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/train_batch6622.jpg'))
plt.axis('off')
# Out:
# (-0.5, 1919.5, 1919.5, -0.5)

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/val_batch0_labels.jpg'))
plt.axis('off')
# Out:
# (-0.5, 1919.5, 1919.5, -0.5)

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/val_batch0_pred.jpg'))
plt.axis('off')
# Out:
# (-0.5, 1919.5, 1919.5, -0.5)

# %%
plt.imshow(plt.imread('/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/val_batch2_pred.jpg'))
plt.axis('off')
# Out:
# (-0.5, 1919.5, 1919.5, -0.5)

# %% [markdown]
# ## Running Inference on Custom Images

# %%
# !yolo predict model='/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/weights/best.pt' source='/content/car.jpeg'
# Out:
# Ultralytics YOLOv8.0.238 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/car.jpeg: 640x640 1 License_Plate, 37.1ms
# Speed: 13.0ms preprocess, 37.1ms inference, 1027.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo predict model='/content/YOLOv8_training_results/YOLOv8 Training Results/runs/detect/train/weights/best.pt' source='/content/car2.jpeg'
# Out:
# Ultralytics YOLOv8.0.238 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m summary (fused): 218 layers, 25840339 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/car2.jpeg: 448x640 1 License_Plate, 115.1ms
# Speed: 3.2ms preprocess, 115.1ms inference, 565.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
